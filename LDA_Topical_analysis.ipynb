# %% [markdown]
# Please click on the round icone to allow nbviewer and see the LDA graphic. Here ----------------------------------------------------------------->
# <br>If the notebook doesn't load on the first try, please reload.
#
# ## Import dependencies
# _____________

# %%
import re
import pandas as pd
import numpy as np
from pprint import pprint

# Spacy + NLTK
import nltk; nltk.download('stopwords')
import spacy
from spacy.lang.fr import French
from nltk.corpus import stopwords
stop_words = stopwords.words('french')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
# !pip install pyLDAvis
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.2.2)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.15)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: pandas>=0.17.0; python_version > "3.5" in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.5)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.36.2)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.19.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0; python_version > "3.5"->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0; python_version > "3.5"->pyLDAvis) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17.0; python_version > "3.5"->pyLDAvis) (1.15.0)

# %%
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop

# %% [markdown]
# ### Divide by phrases
# _____________

# %%
df = pd.read_table("/content/drive/MyDrive/Epitech_DATA-IA/S3_NLP/alice.txt", header=None, sep="delimiter")
print(df)
# Out:
#                                                       0
# 0                                     CHAPITRE PREMIER.
# 1                                   AU FOND DU TERRIER.
# 2     ALICE, assise auprès de sa sœur sur le gazon, ...
# 3     de rester là à ne rien faire; une ou deux fois...
# 4     yeux sur le livre que lisait sa sœur; mais quo...
# ...                                                 ...
# 2670  étranges, et peut-être même en leur contant le...
# 2671  Merveilles du temps jadis: elle la voyait part...
# 2672  chagrins et trouver plaisir à leurs innocentes...
# 2673         propre enfance et les heureux jours d'été.
# 2674                                               FIN.
#
# [2675 rows x 1 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py:767: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_csv(**locals())

# %% [markdown]
# ### Convert to list
# _________

# %%
data = df.values.tolist()

#Check result
pprint(data[:1])
# Out:
# [['CHAPITRE PREMIER.']]

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations 
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  

data_words = list(sent_to_words(data))

print(data_words[:50])
# Out:
# [['chapitre', 'premier'], ['au', 'fond', 'du', 'terrier'], ['alice', 'assise', 'aupres', 'de', 'sa', 'sœur', 'sur', 'le', 'gazon', 'commencait', 'ennuyer'], ['de', 'rester', 'la', 'ne', 'rien', 'faire', 'une', 'ou', 'deux', 'fois', 'elle', 'avait', 'jete', 'les'], ['yeux', 'sur', 'le', 'livre', 'que', 'lisait', 'sa', 'sœur', 'mais', 'quoi', 'pas', 'images', 'pas', 'de'], ['dialogues', 'la', 'belle', 'avance', 'pensait', 'alice', 'qu', 'un', 'livre', 'sans', 'images'], ['sans', 'causeries'], ['elle', 'etait', 'mise', 'reflechir', 'tant', 'bien', 'que', 'mal', 'car', 'la', 'chaleur', 'du'], ['jour', 'endormait', 'et', 'la', 'rendait', 'lourde', 'se', 'demandant', 'si', 'le', 'plaisir', 'de'], ['faire', 'une', 'couronne', 'de', 'marguerites', 'valait', 'bien', 'la', 'peine', 'de', 'se', 'lever', 'et'], ['de', 'cueillir', 'les', 'fleurs', 'quand', 'tout', 'coup', 'un', 'lapin', 'blanc', 'aux', 'yeux', 'roses'], ['passa', 'pres', 'elle'], ['il', 'avait', 'rien', 'la', 'de', 'bien', 'etonnant', 'et', 'alice', 'ne', 'trouva', 'meme', 'pas'], ['tres', 'extraordinaire', 'entendre', 'parler', 'le', 'lapin', 'qui', 'se', 'disait', 'ah'], ['arriverai', 'trop', 'tard', 'en', 'songeant', 'apres', 'il', 'lui', 'sembla', 'bien'], ['qu', 'elle', 'aurait', 'du', 'en', 'etonner', 'mais', 'sur', 'le', 'moment', 'cela', 'lui', 'avait', 'paru'], ['tout', 'naturel', 'cependant', 'quand', 'le', 'lapin', 'vint', 'tirer', 'une', 'montre', 'de'], ['son', 'gousset', 'la', 'regarda', 'puis', 'se', 'prit', 'courir', 'de', 'plus', 'belle', 'alice'], ['sauta', 'sur', 'ses', 'pieds', 'frappee', 'de', 'cette', 'idee', 'que', 'jamais', 'elle', 'avait', 'vu'], ['de', 'lapin', 'avec', 'un', 'gousset', 'et', 'une', 'montre', 'entrainee', 'par', 'la', 'curiosite', 'elle'], ['elanca', 'sur', 'ses', 'traces', 'travers', 'le', 'champ', 'et', 'arriva', 'tout', 'juste'], ['temps', 'pour', 'le', 'voir', 'disparaitre', 'dans', 'un', 'large', 'trou', 'au', 'pied', 'une', 'haie'], ['un', 'instant', 'apres', 'alice', 'etait', 'la', 'poursuite', 'du', 'lapin', 'dans', 'le', 'terrier'], ['sans', 'songer', 'comment', 'elle', 'en', 'sortirait'], ['pendant', 'un', 'bout', 'de', 'chemin', 'le', 'trou', 'allait', 'tout', 'droit', 'comme', 'un', 'tunnel'], ['puis', 'tout', 'coup', 'il', 'plongeait', 'une', 'facon', 'si'], ['brusque', 'qu', 'alice', 'se', 'sentit', 'tomber', 'comme', 'dans', 'un', 'puits', 'une', 'grande'], ['profondeur', 'avant', 'meme', 'avoir', 'pense', 'se', 'retenir'], ['de', 'deux', 'choses', 'une', 'ou', 'le', 'puits', 'etait', 'vraiment', 'bien', 'profond', 'ou', 'elle'], ['tombait', 'bien', 'doucement', 'car', 'elle', 'eut', 'tout', 'le', 'loisir', 'dans', 'sa', 'chute', 'de'], ['regarder', 'autour', 'elle', 'et', 'de', 'se', 'demander', 'avec', 'etonnement', 'ce', 'qu', 'elle'], ['allait', 'devenir', 'abord', 'elle', 'regarda', 'dans', 'le', 'fond', 'du', 'trou', 'pour', 'savoir'], ['ou', 'elle', 'allait', 'mais', 'il', 'faisait', 'bien', 'trop', 'sombre', 'pour', 'rien', 'voir'], ['ensuite', 'elle', 'porta', 'les', 'yeux', 'sur', 'les', 'parois', 'du', 'puits', 'et', 'apercut'], ['qu', 'elles', 'etaient', 'garnies', 'armoires', 'et', 'etageres', 'ca', 'et', 'la', 'elle', 'vit'], ['pendues', 'des', 'clous', 'des', 'cartes', 'geographiques', 'et', 'des', 'images', 'en', 'passant'], ['elle', 'prit', 'sur', 'un', 'rayon', 'un', 'pot', 'de', 'confiture', 'portant', 'cette', 'etiquette'], ['marmelade', 'oranges', 'mais', 'son', 'grand', 'regret', 'le', 'pot', 'etait', 'vide'], ['elle', 'osait', 'le', 'laisser', 'tomber', 'dans', 'la', 'crainte', 'de', 'tuer', 'quelqu', 'un', 'aussi'], ['arrangea', 'elle', 'de', 'maniere', 'le', 'deposer', 'en', 'passant', 'dans', 'une', 'des'], ['armoires'], ['certes', 'dit', 'alice', 'apres', 'une', 'chute', 'pareille', 'je', 'ne', 'me', 'moquerai', 'pas'], ['mal', 'de', 'degringoler', 'escalier', 'comme', 'ils', 'vont', 'me', 'trouver', 'brave', 'chez'], ['nous', 'je', 'tomberais', 'du', 'haut', 'des', 'toits', 'que', 'je', 'n ...

# %% [markdown]
# ### Remove stop words
# _________

# %%
# Define function for stopwords
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# %% [markdown]
# ### Prepare bigrams & trigrams
# _________

# %%
# Define functions for bigrams and trigrams
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# ['chapitre', 'premier']

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# %% [markdown]
# ### Lemmatization
# _________

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
#    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
from spacy.lang.fr import French
spacy.cli.download("fr_core_news_md")

nlp = spacy.load('fr_core_news_md', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:100])
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_md')
# [['chapitre', 'premier'], ['fond', 'terrier'], ['alice', 'assise', 'aupre', 'commencer', 'ennuyer'], ['faire', 'fois', 'jete'], ['oeil', 'livre', 'lire', 'sœur', 'image'], ['dialogue', 'bel', 'avance', 'alice', 'livre', 'image'], ['causerie'], ['eter', 'mise', 'reflechir', 'tant', 'bien', 'mal', 'chaleur'], ['jour', 'endormir', 'lourd', 'demander', 'plaisir'], ['faire', 'couronne', 'marguerite', 'valoir', 'bien', 'peine', 'lever'], ['cueillir', 'fleur', 'quand', 'coup', 'oeil', 'rose'], ['passer', 'pre'], ['bien', 'etonner', 'alice', 'trouver', 'meme'], ['tre', 'extraordinaire', 'entendre', 'parler', 'lapin', 'dire', 'ah'], ['arriverai', 'trop', 'tard', 'apre', 'bien'], ['etonner', 'moment', 'paraître'], ['naturel', 'cependant', 'venir', 'tirer', 'montre'], ['gousset', 'regarder', 'prendre', 'courir', 'plus', 'bel', 'alice'], ['sauter', 'pieds', 'frappee', 'idee', 'jamais', 'voir'], ['lapin', 'gousset', 'montre', 'curiosite'], ['trace', 'travers', 'arriver', 'tout', 'juste'], ['temps', 'voir', 'disparaitre', 'large', 'trou', 'pied', 'haie'], ['apre', 'alice', 'eter', 'poursuite', 'terrier'], ['songer', 'comment', 'sortir'], ['bout', 'chemin', 'trou', 'aller', 'droit', 'tunnel'], ['coup', 'plonger', 'facon'], ['brusque', 'alice', 'tomber', 'puits', 'grand'], ['profondeur', 'meme', 'retenir'], ['chose', 'puit', 'eter', 'vraiment', 'bien', 'profond'], ['tomber', 'bien', 'doucement', 'loisir', 'chute'], ['regarder', 'autour', 'demander', 'etonnement'], ['aller', 'devenir', 'abord', 'regarder', 'fond', 'trou', 'savoir'], ['faire', 'bien', 'trop', 'sombre', 'voir'], ['ensuite', 'porter', 'oeil', 'paroi', 'puits'], ['garnir', 'armoire', 'etagere', 'voir'], ['pendu', 'clou', 'carte', 'geographique', 'image', 'passer'], ['prendre', 'rayon', 'pot', 'confiture', 'porter', 'etiquette'], ['marmelade', 'orange', 'grand', 'regret', 'pot', 'vide'], ['oser', 'laisser', 'tomber', 'crainte', 'tuer', 'quelqu', 'aussi'], ['arranger', 'maniere', 'deposer', 'passer'], ['armoire'], ['certes', 'dire', 'alice', 'apre', 'chute', 'pareil', 'moquerai'], ['mal', 'escalier', 'trouver', 'brave'], ['tomberai', 'haut', 'toit', 'entendre'], ['plainte', 'eter', 'bien', 'probable'], ['tombe', 'tombe', 'chute', 'finir', 'donc'], ['curieux', 'savoir', 'combien', 'mille', 'deja', 'fait', 'dire', 'tout'], ['haut', 'devoir', 'bien', 'pre', 'centre', 'terre', 'voir', 'donc'], ['mill', 'mille', 'profondeur'], ['voyez', 'alice', 'apprendre', 'mal', 'chose', 'lecon', 'bien'], ['tre', 'bon', 'occasion', 'faire', 'parade'], ['savoir', 'voir', 'point', 'auditeur', 'cependant', 'eter', 'bon'], ['exercice', 'repeter', 'oui', 'bien', 'peu', 'pre'], ['alors', 'degre', 'latitude'], ['trouve', 'alice', 'moindre', 'idee', 'dire'], ['latitude', 'grand', 'mot', 'paraître', 'beal'], ['sonore'], ['bientot', 'reprendre', 'traverser', 'completement', 'terre'], ['drol', 'trouver', 'milieu', 'gens', 'marcher'], ['tete', 'bas', 'antipathie', 'eter'], ['fois', 'personn', 'entendre', 'mot'], ['faire', 'effet', 'bien', 'juste'], ['demander', 'nom', 'pays', 'pardon', 'Monsieur', 'ici', 'nouveau', 'zembl'], ['mem', 'temps', 'faire', 'reverence'], ['idee', 'faire', 'reverence', 'air', 'peu', 'comment'], ['petit', 'ignorant', 'penser', 'dame'], ['faire', 'question', 'non', 'falloir', 'demander'], ['part'], ['tombe', 'donc', 'alice', 'faut', 'mieux'], ['faire', 'parler', 'remarquer', 'absence', 'soir'], ['bien', 'eter', 'chat', 'oublier'], ['donner', 'jatte', 'ler', 'heure', 'minette'], ['ici', 'air'], ['bien', 'peur', 'attraper', 'chauve'], ['ressemble', 'beaucoup', 'savoir', 'chat', 'manger'], ['chauve', 'ici', 'sommeil', 'commencer', 'gagner', 'alice'], ['endormie', 'chat', 'manger'], ['chat', 'manger', 'quelquefois'], ['chauve', 'manger', 'chat', 'comprendre', 'bien'], ['repondre', 'autre'], ['question', 'peu', 'poser'], ['commencer', 'rever', 'promener', 'tenir', 'dinah', 'main'], ['dire', 'tre', 'serieusement', 'voir', 'verite'], ['jamais', 'mang', 'quand', 'coup', 'pouf', 'voila'], ['etendue ...

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
#print(corpus[:20])

# %% [markdown]
# ### LDA
# _________

# %%
# Build LDA model
# %%capture output
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=300,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keywords in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.032*"tout" + 0.031*"roi" + 0.027*"trouver" + 0.024*"autour" + '
#   '0.022*"vouloir" + 0.020*"tandis" + 0.019*"salle" + 0.016*"suivre" + '
#   '0.015*"porte" + 0.015*"chercher"'),
#  (1,
#   '0.191*"dire" + 0.099*"alice" + 0.082*"faire" + 0.073*"bien" + '
#   '0.028*"chapelier" + 0.027*"griffon" + 0.027*"voix" + 0.024*"regarder" + '
#   '0.024*"air" + 0.015*"loir"'),
#  (2,
#   '0.047*"continuer" + 0.044*"peu" + 0.041*"alice" + 0.036*"demander" + '
#   '0.035*"jamais" + 0.018*"pouvoir" + 0.014*"nouveau" + 0.013*"question" + '
#   '0.012*"avoir" + 0.012*"personne"'),
#  (3,
#   '0.074*"plus" + 0.045*"aller" + 0.044*"donc" + 0.039*"alors" + 0.034*"oeil" '
#   '+ 0.032*"illustration" + 0.020*"encore" + 0.017*"voila" + 0.017*"pauvre" + '
#   '0.015*"long"'),
#  (4,
#   '0.059*"mettre" + 0.041*"non" + 0.034*"falloir" + 0.031*"chose" + '
#   '0.025*"commencer" + 0.021*"comment" + 0.019*"enfant" + 0.018*"savoir" + '
#   '0.017*"cœur" + 0.017*"maintenant"'),
#  (5,
#   '0.092*"tout" + 0.054*"tete" + 0.034*"crier" + 0.033*"meme" + '
#   '0.031*"entendre" + 0.027*"duchesse" + 0.027*"parler" + 0.022*"jusqu" + '
#   '0.020*"mot" + 0.019*"important"'),
#  (6,
#   '0.097*"eter" + 0.035*"tre" + 0.031*"alice" + 0.028*"tout" + 0.027*"fois" + '
#   '0.025*"bon" + 0.023*"ici" + 0.023*"pensa" + 0.022*"trop" + 0.018*"cote"'),
#  (7,
#   '0.033*"jure" + 0.031*"fort" + 0.030*"grand" + 0.027*"ajouter" + '
#   '0.019*"chat" + 0.018*"comprendre" + 0.015*"lapin_blanc" + 0.015*"proce" + '
#   '0.014*"vivement" + 0.012*"encore"'),
#  (8,
#   '0.054*"voir" + 0.035*"petit" + 0.025*"pre" + 0.024*"main" + 0.024*"jour" + '
#   '0.021*"apre" + 0.021*"dessus" + 0.021*"haut" + 0.020*"ainsi" + '
#   '0.019*"venir"'),
#  (9,
#   '0.082*"autre" + 0.077*"reine" + 0.041*"temps" + 0.040*"prendre" + '
#   '0.017*"moment" + 0.017*"passer" + 0.016*"reprendre" + 0.015*"enfin" + '
#   '0.013*"oui" + 0.011*"jeu"')]

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.346522  0.064666       1        1  19.647616
# 6     -0.141934 -0.106636       2        1  12.098292
# 5      0.045798 -0.238481       3        1  10.145568
# 3      0.102269  0.104185       4        1   9.249082
# 8      0.096253 -0.023609       5        1   8.705999
# 7      0.080882  0.163807       6        1   8.652745
# 9      0.084775  0.109085       7        1   8.422569
# 4      0.030586  0.028507       8        1   7.940274
# 2     -0.033535  0.046007       9        1   7.927345
# 0      0.081430 -0.147531      10        1   7.210509, topic_info=        Term        Freq       Total Category  logprob  loglift
# 49      dire  418.000000  418.000000  Default  30.0000  30.0000
# 23      eter  131.000000  131.000000  Default  29.0000  29.0000
# 80      tout  167.000000  167.000000  Default  28.0000  28.0000
# 9      faire  202.000000  202.000000  Default  27.0000  27.0000
# 4      alice  318.000000  318.000000  Default  26.0000  26.0000
# ..       ...         ...         ...      ...      ...      ...
# 47   trouver   21.329806   35.484629  Topic10  -3.6280   2.1206
# 281    porte   12.040290   21.637968  Topic10  -4.1999   2.0434
# 80      tout   25.471746  167.694495  Topic10  -3.4506   0.7451
# 46      meme    9.600304   47.517345  Topic10  -4.4263   1.0303
# 266     long    6.473702   22.852646  Topic10  -4.8204   1.3683
#
# [394 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 115       3  0.725581       abord
# 115       8  0.272093       abord
# 1939      8  0.974101  absolument
# 932      10  0.829564    adresser
# 524       3  0.956776     affaire
# ...     ...       ...         ...
# 76        5  0.992154        voir
# 534       1  0.983388        voix
# 404      10  0.935846     vouloir
# 963       1  0.905083        vrai
# 109       8  0.911624    vraiment
#
# [402 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 7, 6, 4, 9, 8, 10, 5, 3, 1])
